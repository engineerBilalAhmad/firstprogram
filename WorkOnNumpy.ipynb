# %%
import numpy as np

# %%
food = np.array(["Smosa" , "pakora" , "Raita"])

# %%
food
# Out:
# array(['Smosa', 'pakora', 'Raita'], dtype='<U6')

# %%
price = np.array([3,4,5])
price
# Out:
# array([3, 4, 5])

# %%
print ("Hello world")
# Out:
# Hello world

# %%
np.arrange(5,55,5)

# %%
a=np.array([[],[]])
